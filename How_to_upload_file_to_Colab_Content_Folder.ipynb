# %% [markdown]
# <a href="https://colab.research.google.com/github/mcansozeri/DeepLearning/blob/master/How_to_upload_file_to_Colab_Content_Folder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **How to upload file(s) to Google Colab Content Folder / Google Colab'a Nasıl Dosya(lar) Yüklenir?**

# %%
import matplotlib.pyplot as plt
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  path = '/content/' + fn
  img = image.load_img(path)
  plt.imshow(img)
# Out:
#      <input type="file" id="files-414ca1a0-2e71-46f6-8db1-5c38ec92493e" name="files[]" multiple disabled />
#      <output id="result-414ca1a0-2e71-46f6-8db1-5c38ec92493e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Reyon-Elma-9b6e.png.jpeg to Reyon-Elma-9b6e.png (5).jpeg
